# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq

import pandas as pd
import numpy as np
df = pd.read_csv('/content/advertising.csv')

data = df.to_numpy()

sales_column = data[:, -1]
max_value = np.max(sales_column)
max_index = np.argmax(sales_column)

max_value, max_index
# C
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 13.1MB/s]
# (27.0, 175)

# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq

import pandas as pd
import numpy as np
df = pd.read_csv('/content/advertising.csv')

data = df.to_numpy()

tv_column = data[:, 0]
average_value = np.mean(tv_column)

average_value
# B
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 13.8MB/s]
# 147.0425

# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq

import pandas as pd
df = pd.read_csv('/content/advertising.csv')

data = df.to_numpy()

count = 0
for sales_value in data[:, -1]:
  if sales_value >= 20:
    count += 1

count
# A
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 10.6MB/s]
# 40

# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq

import pandas as pd
df = pd.read_csv('/content/advertising.csv')

data = df.to_numpy()

filtered_df = df[df['Sales'] >= 15]

mean_radio = filtered_df['Radio'].mean()
mean_radio
# B
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 11.7MB/s]
# 26.22293577981651

# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq

import pandas as pd
import numpy as np
df = pd.read_csv('/content/advertising.csv')

data = df.to_numpy()
filtered_df = df[df['Newspaper'] > np.mean(df['Newspaper'])]

sum_sales = np.sum(filtered_df['Sales'])
sum_sales
# C
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 12.2MB/s]
# 1405.1

# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq

import pandas as pd

df = pd.read_csv('/content/advertising.csv')

data = df.to_numpy()
A = df['Sales'].mean()

# Implement the condition based on data
scores = []
for sales_value in df['Sales']:
    if sales_value > A:
        scores.append("Good")
    elif sales_value < A:
        scores.append("Bad")
    else:
        scores.append("Average")

# Print the result of scores[7:10]
print(scores[7:10])
# C
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 11.7MB/s]
# ['Bad', 'Bad', 'Good']

# %%
# Download data
# !gdown 1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq

import pandas as pd

df = pd.read_csv('/content/advertising.csv')

data = df.to_numpy()

A = df['Sales'].mean()
closest_value = df['Sales'].iloc[(df['Sales'] - A).abs().argmin()]
# .abs(): Lấy giá trị tuyệt đối của hiệu sales_values - A
# .argmin(): Tìm chỉ số của giá trị nhỏ nhất trong mảng các giá trị tuyệt đối.
# .iloc[]: Sử dụng chỉ số này để lấy giá trị tương ứng từ cột "Sales".

# Implement the condition based on data
scores = []
for sales_value in df['Sales']:
    if sales_value > A:
        scores.append("Good")
    elif sales_value < A:
        scores.append("Bad")
    else:
        scores.append("Average")

# Print the result of scores[7:10]
print(scores[7:10])
# C
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1iA0WmVfW88HyJvTBSQDI5vesf-pgKabq
# To: /content/advertising.csv
# 100% 4.06k/4.06k [00:00<00:00, 10.6MB/s]
# ['Bad', 'Bad', 'Good']
